# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)

# %%
data
# Out:
# <Response [200]>

# %% [markdown]
# ## Scraping our first page with requests

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select('table.stats_table')[0]

# %% [markdown]
# ## Parsing our first page with requests

# %%
links = standings_table.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/b8fd03ef/2021-2022/Manchester-City-Stats',
#  '/en/squads/822bd0ba/2021-2022/Liverpool-Stats',
#  '/en/squads/cff3d9bb/Chelsea-Stats',
#  '/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  '/en/squads/18bb7c10/Arsenal-Stats',
#  '/en/squads/19538871/Manchester-United-Stats',
#  '/en/squads/7c21e445/West-Ham-United-Stats',
#  '/en/squads/a2d435b3/Leicester-City-Stats',
#  '/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  '/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  '/en/squads/b2b47a98/Newcastle-United-Stats',
#  '/en/squads/47c64c55/Crystal-Palace-Stats',
#  '/en/squads/cd051869/Brentford-Stats',
#  '/en/squads/8602292d/Aston-Villa-Stats',
#  '/en/squads/33c895d4/Southampton-Stats',
#  '/en/squads/d3fd31cc/Everton-Stats',
#  '/en/squads/5bfb9659/Leeds-United-Stats',
#  '/en/squads/943e8050/2021-2022/Burnley-Stats',
#  '/en/squads/2abfe087/2021-2022/Watford-Stats',
#  '/en/squads/1c781004/2021-2022/Norwich-City-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls = team_urls[0]

# %%
data = requests.get(team_urls)

# %% [markdown]
# ## Extract match stats using pandas and requests

# %%
import pandas as pd
matches = pd.read_html(data.text, match = "Scores & Fixtures")[0]

# %%
matches.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2021-08-07  17:15  Community Shield  FA Community Shield  Sat  Neutral
# 1  2021-08-15  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2021-08-21  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2021-08-28  12:30    Premier League          Matchweek 3  Sat     Home
# 4  2021-09-11  15:00    Premier League          Matchweek 4  Sat     Away
#
#   Result GF GA        Opponent   xG  xGA  Poss  Attendance         Captain  \
# 0      L  0  1  Leicester City  NaN  NaN    57         NaN     Fernandinho
# 1      L  0  1       Tottenham  1.9  1.3    64     58262.0     Fernandinho
# 2      W  5  0    Norwich City  2.7  0.1    67     51437.0  İlkay Gündoğan
# 3      W  5  0         Arsenal  3.8  0.1    80     52276.0  İlkay Gündoğan
# 4      W  1  0  Leicester City  2.9  0.8    61     32087.0  İlkay Gündoğan
#
#   Formation          Referee  Match Report Notes
# 0     4-3-3     Paul Tierney  Match Report   NaN
# 1     4-3-3   Anthony Taylor  Match Report   NaN
# 2     4-3-3     Graham Scott  Match Report   NaN
# 3     4-3-3  Martin Atkinson  Match Report   NaN
# 4     4-3-3     Paul Tierney  Match Report   NaN

# %% [markdown]
# ## Get match shooting stts with requests and pandas

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/b8fd03ef/2021-2022/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2021-2022/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2021-2022/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2021-2022/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
data
# Out:
# <Response [200]>

# %%
shooting = pd.read_html(data.text, match = "Shooting")[0]

# %%
shooting.head()
# Out:
#   For Manchester City                                                     \
#                  Date   Time              Comp                Round  Day
# 0          2021-08-07  17:15  Community Shield  FA Community Shield  Sat
# 1          2021-08-15  16:30    Premier League          Matchweek 1  Sun
# 2          2021-08-21  15:00    Premier League          Matchweek 2  Sat
# 3          2021-08-28  12:30    Premier League          Matchweek 3  Sat
# 4          2021-09-11  15:00    Premier League          Matchweek 4  Sat
#
#                                          ... Standard               Expected  \
#      Venue Result GF GA        Opponent  ...     Dist   FK PK PKatt       xG
# 0  Neutral      L  0  1  Leicester City  ...      NaN  NaN  0     0      NaN
# 1     Away      L  0  1       Tottenham  ...     16.9  1.0  0     0      1.9
# 2     Home      W  5  0    Norwich City  ...     17.3  1.0  0     0      2.7
# 3     Home      W  5  0         Arsenal  ...     14.3  0.0  0     0      3.8
# 4     Away      W  1  0  Leicester City  ...     14.0  0.0  0     0      2.9
#
#                             Unnamed: 25_level_0
#   npxG npxG/Sh G-xG np:G-xG        Match Report
# 0  NaN     NaN  NaN     NaN        Match Report
# 1  1.9    0.11 -1.9    -1.9        Match Report
# 2  2.7    0.17  1.3     1.3        Match Report
# 3  3.8    0.15  1.2     1.2        Match Report
# 4  2.9    0.12 -1.9    -1.9        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Gls', 'Sh', 'SoT', 'SoT%', 'G/Sh', 'G/SoT', 'Dist', 'FK',
#        'PK', 'PKatt', 'xG', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG',
#        'Match Report'],
#       dtype='object')

# %% [markdown]
# ## Cleaning and merging scraped data with pandas

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on = "Date")

# %%
team_data.shape
# Out:
# (58, 25)

# %%
shooting.shape
# Out:
# (59, 26)

# %%
matches.shape
# Out:
# (58, 19)

# %% [markdown]
# ## Scraping data for multiple season and teams with forloops

# %%
years = list(range(2022, 2019, -1))
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    if len(soup.select('table.stats_table')) == 0:
        continue
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        print(team_url)
        
        data = requests.get(team_url)
        try :
            matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        except ValueError:
            print(data.text)
            continue
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        
        data = requests.get(f"https://fbref.com{links[0]}")
        try:
            shooting = pd.read_html(data.text, match="Shooting")[0]
        except ValueError:
            print(links[0])
            print(data.text)
            continue
            
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)
# Out:
# https://fbref.com/en/squads/b8fd03ef/2020-2021/Manchester-City-Stats
# https://fbref.com/en/squads/19538871/2020-2021/Manchester-United-Stats
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
# <title>Please Wait... | Cloudflare</title>
#
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
#
#
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
#     window.addEventListener('DOMContentLoaded', function () {
#       var cookieEl = document.getElementById('cookie-alert');
#       cookieEl.style.display = 'block';
#     })
#   }
# </script>
# <!--<![endif]-->
#
#
#     <script>
#     //<![CDATA[
#     (function(){
#       window._cf_chl_opt={
#         cvId: "2",
#         cType: "managed",
#         cNounce: "56519",
#         cRay: "7330a1f718c5c714",
#         cHash: "dd62506ba3b60f0",
#         cUPMDTk: "\/en\/squads\/19538871\/2020-2021\/Manchester-United-Stats?__cf_chl_tk=QBIoY.MW_L0HmT8vNYQmZxVNlkf9bRWV1r3m5Z5OgIs-1659210724-0-gaNycGzNBz0",
#         cFPWv: "g",
#         cTTimeMs: "1000",
#         cLt: "n",
#         cRq: {
#           ru: "aHR0cHM6Ly9mYnJlZi5jb20vZW4vc3F1YWRzLzE5NTM4ODcxLzIwMjAtMjAyMS9NYW5jaGVzdGVyLVVuaXRlZC1TdGF0cw==",
#           ra: "cHl0aG9uLXJlcXVlc3RzLzIuMjUuMQ==",
#           rm: "R0VU",
#           d: "...",
#           t: "MTY1OTIxMDcyNC45NzgwMDA=",
#           m: "sTOy08h5I7qAp9KoVStdJWti4CZlE1LpWkh02/8QC7g=",
#           i1: "+y//GGcmjeM1+LknO+xRVQ==",
#           i2: "FN2AthkF7jwSlf0YT9HgDw==",
#           zh: "FFqr99jR/1GMyqpdyqWEB2vTdfc2EDuCZqDx8wF7Ek4=",
#           uh: "5GU+jYv2xJ+bCaE/ARmi/DORbiS/v56CW7E0TH4XWQk=",
#           hh: "chRDTXbssyxa+mhwwITbN4e9ZGrI2xuaPzXjtB81p0U=",
#         }
#       };
#     }());
#     //]]>
#     </script>
#
# <style>
#   #cf-wrapper #spinner {width:69px; margin:  auto;}
#   #cf-wrapper #cf-please-wait{text-align:center}
#   .attribution {margin-top: 32px;}
#   .bubbles { background-color: #f58220; width:20px; height: 20px; margin:2px; border-radius:100%; display:inline-block; }
#   #cf-wrapper #challenge-form { padding-top:25px; padding-bottom:25px; }
#   #cf-hcaptcha-container { text-align:center;}
#   #cf-hcaptcha-container iframe { display: inline-block;}
#   @keyframes fader     { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-wrapper #cf-bubbles { width:69px; }
#   @-webkit-keyframes fader { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-bubbles > .bubbles { animation: fader 1.6s infinite;}
#   #cf-bubbles > .bubbles:nth-child(2) { animation-delay: .2s;}
#   #cf-bubbles > .bubbles:nth-child(3) { animation-delay: .4s;}
# </style>
# </head>
# <body>
#   <div id="cf-wrapper">
#     <div class="cf-alert cf-alert-error cf-cookie-error" id="cookie-alert" data-translate="enable_cookies">Please enable cookies.</div>
#     <div id="cf-error-details" class="cf-error-details-wrapper">
#       <div class="cf-wrapper cf-header cf-error-overview">
#
#         <h1 data-translate="managed_challenge_headline">Please wait...</h1>
#         <h2 class="cf-subheadline"><span data-translate="managed_checking_msg">We are checking your browser...</span> fbref.com</h2>
#
#       </div>
#
#       <div class="cf-section cf-highlight cf-captcha-container">
#         <div class="cf-wrapper">
#           <div class="cf-columns two">
#             <div class="cf-column">
#
#               <div class="cf-highlight-inverse cf-form-stacked">
#                 <form id="challenge-form" class="challenge-form managed-form" action="/en/squads/19538871/2020-2021/Manchester-United-Stats?__cf_chl_f_tk=QBIoY.MW_L0HmT8vNYQmZxVNlkf9bRWV1r3m5Z5OgIs-1659210724-0-gaNycGzNBz0" method="POST" enctype="application/x-www-form-urlencoded">
#     <div id='cf-please-wait'>
#       <div id='spinner'>
#         <div id="cf-bubbles">
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#         </div>
#       </div>
#       <p data-translate="please_wait" id="cf-spinner-please-wait">Please stand by, while we are checking your browser...</p>
#       <p data-translate="redirecting" id="cf-spinner-redirecting" style="display:none">Redirecting...</p>
#       </div>
#   <input type="hidden" name="md" value="taWwv1eqLDyENd7PKx3Px46ve02gMz8.seqL3mu94xA-1659210724-0-AVx6u5BDsAzgKXK5-QZ0_f6Cow1JcyVduJYvcZldAh1Xi8k5TUwQ8bGAQ8RB2Q35GrVrnSuuzIGgmE9-ECcjQSnu_DUckD7GsNYdhD-QYgonVsJZLBSNH1MP2mwC4T8S0zGkWNo4Ns4oipS_1FTr783KgftuwwCzvvbivyRWpXfgM2WZaIRd5F7ikry4iTwk6YWZsFyEF9ZQFVMCEcuv2Xnwm-zk6FCDDvVAVUbcBu-kLiEHfDrrrsUm9Eej2TcQ-T4FaGMDnfFoZZnGaud5EN7BYdEJaXvA_fBFzE0TUCra6jR0wVkUOKzUYSHpeY1j2ucFNvt6j2zOJyBxAGNmsFWcNkA0vfbeCv84f1NCzV5IRe61iMqrdRNo1cMjxPtNif9JyiqyRpwyJXq0hIj1OgA8b3tNvZVxH3VLVDBo0sVH2rfYjLc56s4OpXE-pqFW945hDRZfiQuaoKpRu5IF-91398lhMFLuK9GXC53jwRw_F4LyUOvIkGTWLWvrf4c2uCand_HVLhOcc7-hoFrRoC9oMm3DPlW4MRlh0wv0AKLXEbxeF_OzbltzoOXJEiwei0OSC1aLlvWsCSL9tSSEw_cZA-kireAmGN--5VGlpjLBkDHukW1GRg3f1IZm465pIjAHE5c2AYRoZEhAjiyeFvF4LJEWE4ZX5aPAKVDnKgje2CxmRjJudcku4cCeR_3r01Yzx1COWAcW51BbcAOptorNFB4-r27JusGOlcp0lWWBGrBWNovm500LRQtl3j89pYHpkk_OxWP3NlTwevUOI6Eh9NT3IrXA5ULFvzQE_p8qGhnYaX9tGXHweMKaaaNLdY4gbl17PXtqghsaTYe4vdlk6wjvCBwJQGdJ_YTT5z_S" />
#   <input type="hidden" name="r" value="zIx9UcKvRj5LWCxwEXse1IbY98R6oSjLpFAgshKedY8-1659210724-0-...">
#   <noscript id="cf-captcha-bookmark" class="cf-captcha-info">
#   <h1 data-translate="turn_on_js" style="color:#bd2426;">Please turn JavaScript on and reload the page.</h1>
#   </noscript>
#     <div id="no-cookie-warning" class="cookie-warning" data-translate="turn_on_cookies" style="display:none">
#       <p data-translate="turn_on_cookies" style="color:#bd2426;">Please enable Cookies and reload the page.</p>
#     </div>
#   <script>
#   //<![CDATA[
#     var a = function() {try{return !!window.addEventListener} catch(e) {return !1} },
#       b = function(b, c) {a() ? document.addEventListener("DOMContentLoaded", b, c) : document.attachEvent("onreadystatechange", b)};
#       b(function(){
#         var cookiesEnabled=(navigator.cookieEnabled)? true : false;
#         if(!cookiesEnabled){
#           var q = document.getElementById('no-cookie-warning');q.style.display = 'block';
#         }
#       });
#   //]]>
#   </script>
#   <div id="trk_captcha_js" style="background-image:url('/cdn-cgi/images/trace/captcha/nojs/transparent.gif?ray=7330a1f718c5c714')"></div>
# </form>
#   <script>
#     //<![CDATA[
#     (function(){
#         var isIE = /(MSIE|Trident\/|Edge\/)/i.test(window.navigator.userAgent);
#         var trkjs = isIE ? new Image() : document.createElement('img');
#         trkjs.setAttribute("src", "/cdn-cgi/images/trace/managed/js/transparent.gif?ray=7330a1f718c5c714");
#         trkjs.id = "trk_managed_js";
#         trkjs.setAttribute("alt", "");
#         document.body.appendChild(trkjs);
#         var cpo=document.createElement('script');
#         cpo.type='text/javascript';
#         cpo.src = '/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=7330a1f718c5c714';
#
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, -window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window._cf_chl_opt.cUPMDTk && window.history && window.history.replaceState) {
#           var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#           history.replaceState(null, null, "\/en\/squads\/19538871\/2020-2021\/Manchester-United-Stats?__cf_chl_rt_tk=QBIoY.MW_L0HmT8vNYQmZxVNlkf9bRWV1r3m5Z5OgIs-1659210724-0-gaNycGzNBz0" + window._cf_chl_opt.cOgUHash);
#           cpo.onload = function() {
#             history.replaceState(null, null, ogU);
#           };
#         }
#
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#     //]]>
#     </script>
#
#
#               </div>
#             </div>
#
#             <div class="cf-column">
#               <div class="cf-screenshot-container">
#
#                 <span class="cf-no-screenshot"></span>
#
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#
#       <div class="cf-section cf-wrapper">
#         <div class="cf-columns two">
#           <div class="cf-column">
#             <h2 data-translate="why_captcha_headline">Why do I have to complete a CAPTCHA?</h2>
#
#             <p data-translate="why_captcha_detail">Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.</p>
#           </div>
#
#           <div class="cf-column">
#             <h2 data-translate="resolve_captcha_headline">What can I do to prevent this in the future?</h2>
#
#
#             <p data-translate="resolve_captcha_antivirus">If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.</p>
#
#             <p data-translate="resolve_captcha_network">If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.</p>
#
#
#
#           </div>
#         </div>
#       </div>
#
#
#       <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">7330a1f718c5c714</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">196.127.99.247</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
#   </div>
#
#   <script>
#   window._cf_translation = {};
#
#
# </script>
#
#
# </body>
# </html>
#
# https://fbref.com/en/squads/822bd0ba/2020-2021/Liverpool-Stats
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
# <title>Please Wait... | Cloudflare</title>
#
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
#
#
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
#     window.addEventListener('DOMContentLoaded', function () {
#       var cookieEl = document.getElementById('cookie-alert');
#       cookieEl.style.display = 'block';
#     })
#   }
# </script>
# <!--<![endif]-->
#
#
#     <script>
#     //<![CDATA[
#     (function(){
#       window._cf_chl_opt={
#         cvId: "2",
#         cType: "managed",
#         cNounce: "10352",
#         cRay: "7330a1f78c39c724",
#         cHash: "b039b6b2b4d0fb4",
#         cUPMDTk: "\/en\/squads\/822bd0ba\/2020-2021\/Liverpool-Stats?__cf_chl_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0",
#         cFPWv: "g",
#         cTTimeMs: "1000",
#         cLt: "n",
#         cRq: {
#           ru: "aHR0cHM6Ly9mYnJlZi5jb20vZW4vc3F1YWRzLzgyMmJkMGJhLzIwMjAtMjAyMS9MaXZlcnBvb2wtU3RhdHM=",
#           ra: "cHl0aG9uLXJlcXVlc3RzLzIuMjUuMQ==",
#           rm: "R0VU",
#           d: "...",
#           t: "MTY1OTIxMDcyNS4wNTUwMDA=",
#           m: "+s1SMgZB98efIUqIeRb4hONbSh+0cwXVdlhhI9bzS24=",
#           i1: "m/3uKtboDTUdk71R7+mVNw==",
#           i2: "wyGBrIZyRyq7SLiGGEJzTQ==",
#           zh: "FFqr99jR/1GMyqpdyqWEB2vTdfc2EDuCZqDx8wF7Ek4=",
#           uh: "5GU+jYv2xJ+bCaE/ARmi/DORbiS/v56CW7E0TH4XWQk=",
#           hh: "chRDTXbssyxa+mhwwITbN4e9ZGrI2xuaPzXjtB81p0U=",
#         }
#       };
#     }());
#     //]]>
#     </script>
#
# <style>
#   #cf-wrapper #spinner {width:69px; margin:  auto;}
#   #cf-wrapper #cf-please-wait{text-align:center}
#   .attribution {margin-top: 32px;}
#   .bubbles { background-color: #f58220; width:20px; height: 20px; margin:2px; border-radius:100%; display:inline-block; }
#   #cf-wrapper #challenge-form { padding-top:25px; padding-bottom:25px; }
#   #cf-hcaptcha-container { text-align:center;}
#   #cf-hcaptcha-container iframe { display: inline-block;}
#   @keyframes fader     { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-wrapper #cf-bubbles { width:69px; }
#   @-webkit-keyframes fader { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-bubbles > .bubbles { animation: fader 1.6s infinite;}
#   #cf-bubbles > .bubbles:nth-child(2) { animation-delay: .2s;}
#   #cf-bubbles > .bubbles:nth-child(3) { animation-delay: .4s;}
# </style>
# </head>
# <body>
#   <div id="cf-wrapper">
#     <div class="cf-alert cf-alert-error cf-cookie-error" id="cookie-alert" data-translate="enable_cookies">Please enable cookies.</div>
#     <div id="cf-error-details" class="cf-error-details-wrapper">
#       <div class="cf-wrapper cf-header cf-error-overview">
#
#         <h1 data-translate="managed_challenge_headline">Please wait...</h1>
#         <h2 class="cf-subheadline"><span data-translate="managed_checking_msg">We are checking your browser...</span> fbref.com</h2>
#
#       </div>
#
#       <div class="cf-section cf-highlight cf-captcha-container">
#         <div class="cf-wrapper">
#           <div class="cf-columns two">
#             <div class="cf-column">
#
#               <div class="cf-highlight-inverse cf-form-stacked">
#                 <form id="challenge-form" class="challenge-form managed-form" action="/en/squads/822bd0ba/2020-2021/Liverpool-Stats?__cf_chl_f_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0" method="POST" enctype="application/x-www-form-urlencoded">
#     <div id='cf-please-wait'>
#       <div id='spinner'>
#         <div id="cf-bubbles">
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#         </div>
#       </div>
#       <p data-translate="please_wait" id="cf-spinner-please-wait">Please stand by, while we are checking your browser...</p>
#       <p data-translate="redirecting" id="cf-spinner-redirecting" style="display:none">Redirecting...</p>
#       </div>
#   <input type="hidden" name="md" value="HMpar6sk2eGi0FAi7IsTTVwrTR5O6N2RkIlP3.0D17w-1659210725-0-AUxS1RNsI5JAoB2n-6jlZHJgbWguNBNOshulXRfg5asKjPlgybSb1q0ijWT7-lHzAcGG6DdtLazzOUVG1hc_PjMRUlbQleKVn8AQbFxcaXFkYb6rQlPOcqAIUbUDRV9QJ5olRdAbR7GJ6ws4uydLq42FEP30MRikv3HtCW8fyvIt0QZrJoSm1VLoF_GaylGJHzK1yPVp9FDZjvfIlwFewaLtK2zBa5aXzrfYC6Vyps8XMsTUO1So5tXgGOdzCiylvA1WEWt4lvYwHBW3l35HXX4gFj-SSa9mVUw7x0tYFddVvv2Q1sffeAXRzLYlVevWgP4c21oJ2loNZtQulB2xS2-5jKhLsrW-PLYQw-OaVR5cBLhg25AE6HhaBpIp-FsLnEhRDZ6d0Q8RFFLRHW6-Cw_aGond7gAAMTLwh_cqre4eSCjaa1PtAz7B9TBIWMlxo5BzJch_kcy7L2bQhNOpxS_dkgRGN6aEKksntXctZSmAi9tTKNssM1ywV3qjqlKKRf8Yme4vIr1w7agXBHm3uuxB8HVGuNnRYtliuOWE79-BdZi1ChXglFJC3kaCwXPMvQRUeiCqsLRK5_fBdwmEbmCwB_4wYerNEhyuBd7flqR0Q-21CzJfYdWyjWdCPeh7QFAAYldHLpvTIrT17E_1G2jsLJaLPJQLChQGe5RC1DchEy8SAXIHxTxiVEP04hSrEs9tgIY9HFxcdhGmZzRGNonjjwXDntTyRlhjX_6gSgOOI4KsmaZ-Zuc9SsoMRYjZuppyzInxujDtZl_thYFKYmkbLgAs43iAP_mRcgKj4FmEktDIvIG0N9ZZZv5uikU1iyPGMQbdoQjmrBRmDtIH8-8" />
#   <input type="hidden" name="r" value="WdbgQcZDhQmv7doSJD5Q0aFxtTuTHGFUUeIEZDmt0RA-1659210725-0-...">
#   <noscript id="cf-captcha-bookmark" class="cf-captcha-info">
#   <h1 data-translate="turn_on_js" style="color:#bd2426;">Please turn JavaScript on and reload the page.</h1>
#   </noscript>
#     <div id="no-cookie-warning" class="cookie-warning" data-translate="turn_on_cookies" style="display:none">
#       <p data-translate="turn_on_cookies" style="color:#bd2426;">Please enable Cookies and reload the page.</p>
#     </div>
#   <script>
#   //<![CDATA[
#     var a = function() {try{return !!window.addEventListener} catch(e) {return !1} },
#       b = function(b, c) {a() ? document.addEventListener("DOMContentLoaded", b, c) : document.attachEvent("onreadystatechange", b)};
#       b(function(){
#         var cookiesEnabled=(navigator.cookieEnabled)? true : false;
#         if(!cookiesEnabled){
#           var q = document.getElementById('no-cookie-warning');q.style.display = 'block';
#         }
#       });
#   //]]>
#   </script>
#   <div id="trk_captcha_js" style="background-image:url('/cdn-cgi/images/trace/captcha/nojs/transparent.gif?ray=7330a1f78c39c724')"></div>
# </form>
#   <script>
#     //<![CDATA[
#     (function(){
#         var isIE = /(MSIE|Trident\/|Edge\/)/i.test(window.navigator.userAgent);
#         var trkjs = isIE ? new Image() : document.createElement('img');
#         trkjs.setAttribute("src", "/cdn-cgi/images/trace/managed/js/transparent.gif?ray=7330a1f78c39c724");
#         trkjs.id = "trk_managed_js";
#         trkjs.setAttribute("alt", "");
#         document.body.appendChild(trkjs);
#         var cpo=document.createElement('script');
#         cpo.type='text/javascript';
#         cpo.src = '/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=7330a1f78c39c724';
#
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, -window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window._cf_chl_opt.cUPMDTk && window.history && window.history.replaceState) {
#           var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#           history.replaceState(null, null, "\/en\/squads\/822bd0ba\/2020-2021\/Liverpool-Stats?__cf_chl_rt_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0" + window._cf_chl_opt.cOgUHash);
#           cpo.onload = function() {
#             history.replaceState(null, null, ogU);
#           };
#         }
#
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#     //]]>
#     </script>
#
#
#               </div>
#             </div>
#
#             <div class="cf-column">
#               <div class="cf-screenshot-container">
#
#                 <span class="cf-no-screenshot"></span>
#
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#
#       <div class="cf-section cf-wrapper">
#         <div class="cf-columns two">
#           <div class="cf-column">
#             <h2 data-translate="why_captcha_headline">Why do I have to complete a CAPTCHA?</h2>
#
#             <p data-translate="why_captcha_detail">Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.</p>
#           </div>
#
#           <div class="cf-column">
#             <h2 data-translate="resolve_captcha_headline">What can I do to prevent this in the future?</h2>
#
#
#             <p data-translate="resolve_captcha_antivirus">If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.</p>
#
#             <p data-translate="resolve_captcha_network">If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.</p>
#
#
#
#           </div>
#         </div>
#       </div>
#
#
#       <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">7330a1f78c39c724</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">196.127.99.247</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
#   </div>
#
#   <script>
#   window._cf_translation = {};
#
#
# </script>
#
#
# </body>
# </html>
#
# https://fbref.com/en/squads/cff3d9bb/2020-2021/Chelsea-Stats
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
# <title>Please Wait... | Cloudflare</title>
#
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
#
#
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
#     window.addEventListener('DOMContentLoaded', function () {
#       var cookieEl = document.getElementById('cookie-alert');
#       cookieEl.style.display = 'block';
#     })
#   }
# </script>
# <!--<![endif]-->
#
#
#     <script>
#     //<![CDATA[
#     (function(){
#       window._cf_chl_opt={
#         cvId: "2",
#         cType: "managed",
#         cNounce: "27696",
#         cRay: "7330a1f80f40c72c",
#         cHash: "53f0f20a5a00808",
#         cUPMDTk: "\/en\/squads\/cff3d9bb\/2020-2021\/Chelsea-Stats?__cf_chl_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0",
#         cFPWv: "g",
#         cTTimeMs: "1000",
#         cLt: "n",
#         cRq: {
#           ru: "aHR0cHM6Ly9mYnJlZi5jb20vZW4vc3F1YWRzL2NmZjNkOWJiLzIwMjAtMjAyMS9DaGVsc2VhLVN0YXRz",
#           ra: "cHl0aG9uLXJlcXVlc3RzLzIuMjUuMQ==",
#           rm: "R0VU",
#           d: "...",
#           t: "MTY1OTIxMDcyNS4xMjcwMDA=",
#           m: "JifA26AtpUjls3CnkqTSw4LBYHT3uc1ZsVMkdBD3/ck=",
#           i1: "79utQUggGTe2Rph/B3TyFw==",
#           i2: "9AnwUoNGMjRtJL1zeHacQQ==",
#           zh: "FFqr99jR/1GMyqpdyqWEB2vTdfc2EDuCZqDx8wF7Ek4=",
#           uh: "5GU+jYv2xJ+bCaE/ARmi/DORbiS/v56CW7E0TH4XWQk=",
#           hh: "chRDTXbssyxa+mhwwITbN4e9ZGrI2xuaPzXjtB81p0U=",
#         }
#       };
#     }());
#     //]]>
#     </script>
#
# <style>
#   #cf-wrapper #spinner {width:69px; margin:  auto;}
#   #cf-wrapper #cf-please-wait{text-align:center}
#   .attribution {margin-top: 32px;}
#   .bubbles { background-color: #f58220; width:20px; height: 20px; margin:2px; border-radius:100%; display:inline-block; }
#   #cf-wrapper #challenge-form { padding-top:25px; padding-bottom:25px; }
#   #cf-hcaptcha-container { text-align:center;}
#   #cf-hcaptcha-container iframe { display: inline-block;}
#   @keyframes fader     { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-wrapper #cf-bubbles { width:69px; }
#   @-webkit-keyframes fader { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-bubbles > .bubbles { animation: fader 1.6s infinite;}
#   #cf-bubbles > .bubbles:nth-child(2) { animation-delay: .2s;}
#   #cf-bubbles > .bubbles:nth-child(3) { animation-delay: .4s;}
# </style>
# </head>
# <body>
#   <div id="cf-wrapper">
#     <div class="cf-alert cf-alert-error cf-cookie-error" id="cookie-alert" data-translate="enable_cookies">Please enable cookies.</div>
#     <div id="cf-error-details" class="cf-error-details-wrapper">
#       <div class="cf-wrapper cf-header cf-error-overview">
#
#         <h1 data-translate="managed_challenge_headline">Please wait...</h1>
#         <h2 class="cf-subheadline"><span data-translate="managed_checking_msg">We are checking your browser...</span> fbref.com</h2>
#
#       </div>
#
#       <div class="cf-section cf-highlight cf-captcha-container">
#         <div class="cf-wrapper">
#           <div class="cf-columns two">
#             <div class="cf-column">
#
#               <div class="cf-highlight-inverse cf-form-stacked">
#                 <form id="challenge-form" class="challenge-form managed-form" action="/en/squads/cff3d9bb/2020-2021/Chelsea-Stats?__cf_chl_f_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0" method="POST" enctype="application/x-www-form-urlencoded">
#     <div id='cf-please-wait'>
#       <div id='spinner'>
#         <div id="cf-bubbles">
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#         </div>
#       </div>
#       <p data-translate="please_wait" id="cf-spinner-please-wait">Please stand by, while we are checking your browser...</p>
#       <p data-translate="redirecting" id="cf-spinner-redirecting" style="display:none">Redirecting...</p>
#       </div>
#   <input type="hidden" name="md" value="yd2ihsohBcZjaRM_Fm6camgL8B80FvzzoH6lGZSFKdk-1659210725-0-AeFu-5iKiIbOF-7597UZGkQCS8rG2FtMvmhXM8geyTO-HEi-KtkEIBEleImpfPRuDriihIulVo64F36Gke4VjVfp6zcqesu-8tCiv98YdcFTJ0R_eYfsPL-DLT5fKyr8GY6zSQYHHdGkBAjIyAeKMPUea9OFWKSuTTkU0MjlQXnLv-Nsaa-qVxETGh73_tAauIoB6F0mpe5XzsaFcfNR5q6XN6rIKQ93_7flHOAQWOFKyXdjYQqf_3lfZYV_c2ctu_U-1yyuoCQhqJG5KGdMmbpYn2Mstt8kzvBUW2xiELI2_J1TbBUxlgSHuQUeA5nURMd7rvI8tA2MtN6KjPpB6K5qL3QYn0JjZ7PYyS6KTChdKvJOMOBH1EaanjAbbf1_9W7aV9nijOHlc-7-fpWzVAw9ZkEIqmZa95aBu1YXUQH6fMEfNhpGEZuu44soTJa0SphmVZxB4LmoZHk4xcLtw0RTrZpBcuR2cu2wmxzq1lZiY5m9SZ6uOOLD6Uv1_qNkRELa00S_9d0xyhtc13F_IImUteZdFeXzy2I_CMZMqNfdna_qANat0BQoM2D3U4DLIinhh9vl0E9vEsMb0Q3H-oDmKYddXz_jt-u04diD1ZJ45r0fLJ57M3AvBadMgPIsUWNKL4xopnYJA3f7ioZpO2oj7RrXorsNRaPvUEHSjHzKtcP5Hxw0vbd0kIaWi6jAXjhKgjR230O-UTP8pFPXN6X0MUZQTZemb-WnUHUIoG_69N__u55UBT2OhxSuf4RSzPQoTKpyCyLT8DoHi9-PpHMyfsvn2ZPtsepbA8rKvF4nvo3q1lgrrIP_yySSyE9eLo72qFeCD_HxKh1r2mFqSjo" />
#   <input type="hidden" name="r" value="JuDdmgVb8e75Acg6O6kEmO6ecrweDoMUcAVa6RInonQ-1659210725-0-...">
#   <noscript id="cf-captcha-bookmark" class="cf-captcha-info">
#   <h1 data-translate="turn_on_js" style="color:#bd2426;">Please turn JavaScript on and reload the page.</h1>
#   </noscript>
#     <div id="no-cookie-warning" class="cookie-warning" data-translate="turn_on_cookies" style="display:none">
#       <p data-translate="turn_on_cookies" style="color:#bd2426;">Please enable Cookies and reload the page.</p>
#     </div>
#   <script>
#   //<![CDATA[
#     var a = function() {try{return !!window.addEventListener} catch(e) {return !1} },
#       b = function(b, c) {a() ? document.addEventListener("DOMContentLoaded", b, c) : document.attachEvent("onreadystatechange", b)};
#       b(function(){
#         var cookiesEnabled=(navigator.cookieEnabled)? true : false;
#         if(!cookiesEnabled){
#           var q = document.getElementById('no-cookie-warning');q.style.display = 'block';
#         }
#       });
#   //]]>
#   </script>
#   <div id="trk_captcha_js" style="background-image:url('/cdn-cgi/images/trace/captcha/nojs/transparent.gif?ray=7330a1f80f40c72c')"></div>
# </form>
#   <script>
#     //<![CDATA[
#     (function(){
#         var isIE = /(MSIE|Trident\/|Edge\/)/i.test(window.navigator.userAgent);
#         var trkjs = isIE ? new Image() : document.createElement('img');
#         trkjs.setAttribute("src", "/cdn-cgi/images/trace/managed/js/transparent.gif?ray=7330a1f80f40c72c");
#         trkjs.id = "trk_managed_js";
#         trkjs.setAttribute("alt", "");
#         document.body.appendChild(trkjs);
#         var cpo=document.createElement('script');
#         cpo.type='text/javascript';
#         cpo.src = '/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=7330a1f80f40c72c';
#
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, -window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window._cf_chl_opt.cUPMDTk && window.history && window.history.replaceState) {
#           var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#           history.replaceState(null, null, "\/en\/squads\/cff3d9bb\/2020-2021\/Chelsea-Stats?__cf_chl_rt_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0" + window._cf_chl_opt.cOgUHash);
#           cpo.onload = function() {
#             history.replaceState(null, null, ogU);
#           };
#         }
#
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#     //]]>
#     </script>
#
#
#               </div>
#             </div>
#
#             <div class="cf-column">
#               <div class="cf-screenshot-container">
#
#                 <span class="cf-no-screenshot"></span>
#
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#
#       <div class="cf-section cf-wrapper">
#         <div class="cf-columns two">
#           <div class="cf-column">
#             <h2 data-translate="why_captcha_headline">Why do I have to complete a CAPTCHA?</h2>
#
#             <p data-translate="why_captcha_detail">Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.</p>
#           </div>
#
#           <div class="cf-column">
#             <h2 data-translate="resolve_captcha_headline">What can I do to prevent this in the future?</h2>
#
#
#             <p data-translate="resolve_captcha_antivirus">If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.</p>
#
#             <p data-translate="resolve_captcha_network">If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.</p>
#
#
#
#           </div>
#         </div>
#       </div>
#
#
#       <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">7330a1f80f40c72c</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">196.127.99.247</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
#   </div>
#
#   <script>
#   window._cf_translation = {};
#
#
# </script>
#
#
# </body>
# </html>
#
# https://fbref.com/en/squads/a2d435b3/2020-2021/Leicester-City-Stats
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
# <title>Please Wait... | Cloudflare</title>
#
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
#
#
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
#     window.addEventListener('DOMContentLoaded', function () {
#       var cookieEl = document.getElementById('cookie-alert');
#       cookieEl.style.display = 'block';
#     })
#   }
# </script>
# <!--<![endif]-->
#
#
#     <script>
#     //<![CDATA[
#     (function(){
#       window._cf_chl_opt={
#         cvId: "2",
#         cType: "managed",
#         cNounce: "81556",
#         cRay: "7330a1f87f6bc72c",
#         cHash: "d4790f778c56ab7",
#         cUPMDTk: "\/en\/squads\/a2d435b3\/2020-2021\/Leicester-City-Stats?__cf_chl_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0",
#         cFPWv: "g",
#         cTTimeMs: "1000",
#         cLt: "n",
#         cRq: {
#           ru: "aHR0cHM6Ly9mYnJlZi5jb20vZW4vc3F1YWRzL2EyZDQzNWIzLzIwMjAtMjAyMS9MZWljZXN0ZXItQ2l0eS1TdGF0cw==",
#           ra: "cHl0aG9uLXJlcXVlc3RzLzIuMjUuMQ==",
#           rm: "R0VU",
#           d: "...",
#           t: "MTY1OTIxMDcyNS4yMDEwMDA=",
#           m: "5sOwcNXr+7yPEjtAYshZ2reEt0jF4MPJOYYrSRJTcXY=",
#           i1: "mXwQJ+819p1cbYvR17Jq0Q==",
#           i2: "IM22pbgRiil77Uw5055Fmg==",
#           zh: "FFqr99jR/1GMyqpdyqWEB2vTdfc2EDuCZqDx8wF7Ek4=",
#           uh: "5GU+jYv2xJ+bCaE/ARmi/DORbiS/v56CW7E0TH4XWQk=",
#           hh: "chRDTXbssyxa+mhwwITbN4e9ZGrI2xuaPzXjtB81p0U=",
#         }
#       };
#     }());
#     //]]>
#     </script>
#
# <style>
#   #cf-wrapper #spinner {width:69px; margin:  auto;}
#   #cf-wrapper #cf-please-wait{text-align:center}
#   .attribution {margin-top: 32px;}
#   .bubbles { background-color: #f58220; width:20px; height: 20px; margin:2px; border-radius:100%; display:inline-block; }
#   #cf-wrapper #challenge-form { padding-top:25px; padding-bottom:25px; }
#   #cf-hcaptcha-container { text-align:center;}
#   #cf-hcaptcha-container iframe { display: inline-block;}
#   @keyframes fader     { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-wrapper #cf-bubbles { width:69px; }
#   @-webkit-keyframes fader { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-bubbles > .bubbles { animation: fader 1.6s infinite;}
#   #cf-bubbles > .bubbles:nth-child(2) { animation-delay: .2s;}
#   #cf-bubbles > .bubbles:nth-child(3) { animation-delay: .4s;}
# </style>
# </head>
# <body>
#   <div id="cf-wrapper">
#     <div class="cf-alert cf-alert-error cf-cookie-error" id="cookie-alert" data-translate="enable_cookies">Please enable cookies.</div>
#     <div id="cf-error-details" class="cf-error-details-wrapper">
#       <div class="cf-wrapper cf-header cf-error-overview">
#
#         <h1 data-translate="managed_challenge_headline">Please wait...</h1>
#         <h2 class="cf-subheadline"><span data-translate="managed_checking_msg">We are checking your browser...</span> fbref.com</h2>
#
#       </div>
#
#       <div class="cf-section cf-highlight cf-captcha-container">
#         <div class="cf-wrapper">
#           <div class="cf-columns two">
#             <div class="cf-column">
#
#               <div class="cf-highlight-inverse cf-form-stacked">
#                 <form id="challenge-form" class="challenge-form managed-form" action="/en/squads/a2d435b3/2020-2021/Leicester-City-Stats?__cf_chl_f_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0" method="POST" enctype="application/x-www-form-urlencoded">
#     <div id='cf-please-wait'>
#       <div id='spinner'>
#         <div id="cf-bubbles">
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#         </div>
#       </div>
#       <p data-translate="please_wait" id="cf-spinner-please-wait">Please stand by, while we are checking your browser...</p>
#       <p data-translate="redirecting" id="cf-spinner-redirecting" style="display:none">Redirecting...</p>
#       </div>
#   <input type="hidden" name="md" value="pywtfkrxWp8maRSs3VX2Hq4zAAOlZ1YqeokmRTyVawA-1659210725-0-AZy5NucfJHk15vG7edxVFXfKUhcXiugRdChZgzd8PKr9wnSx6T2H1w8L4VOTY6OVInYeiaiN9Il-zMeLz5QSELAyTHU_X0nCMnFnoArWweGvIMsCRhkTmpQHZokHfIJyLMavra1yv_zIqfMTh1VF-xc756vLY6pnmfP5qrTuSZ7gHSz5yZCR7QEWAdRmg1SNO72M_6DXOEttzbZBXdmOTTqwTTL0TOkAbot5w2wTIiBDpIp76BxplpCiTZlr5ZCJJdmN9RySuLY_7gwbifwCK4vbCiE8CxqHhdbsvv3SJFaOVhLVyWSZwHHiAfr90v1VCE5XioKsD4IVFXDtIpfo52mT6ghy9TlTgG4LHAMGTrY3yWSB0RCbR603rmugz0H3vtPoZZD225pK939-d_kyX96aYXww-ZAkb3TfKyBZ4ZuAD_ZhyrgMfxuY952Fh8LId_8Sc4ukTJs80ZOGdi6cbbUYU5WB4CQSXPH4IMtyaSa05O5oFLraniZdPVA2CgNv7AXEpJoiWy9qM6tNPzYeiHsVTMRXsDrwSTd0i0UoNgheJrdrdm_Qc1RcFVEaiz0iCEOlkSMM1jZVg55iXtGV3qYsyB_hYfdfsZxdCS_qvupL37gE0qBkGfhwNUgOJsrbsNcqdgSCWNRHW57T2lrpPIARl7LD_dg6_WqyZY9Q4lya2BRpDeixMuwviEjtgLZN1C7C2JbnOVElKJqb7cmr3S6F9mKM7GSLgVjHqIhVGdPLpzHVKjuQKzjzpSSubDpf4py8uqczghD-CZG1AwrBaj32wBJA369DbZfFvx-fyltXdRR43-TlTG8P_sio1YR7NQ0kTEcqwpIog0Ptr-KWfGH8RcxgF0QUib7K48C5Jyxh" />
#   <input type="hidden" name="r" value="OdlJ0DPmdZ2JktrZsYQ8zDj3S6M6.mF1tmv_Ia6X3b4-1659210725-0-...">
#   <noscript id="cf-captcha-bookmark" class="cf-captcha-info">
#   <h1 data-translate="turn_on_js" style="color:#bd2426;">Please turn JavaScript on and reload the page.</h1>
#   </noscript>
#     <div id="no-cookie-warning" class="cookie-warning" data-translate="turn_on_cookies" style="display:none">
#       <p data-translate="turn_on_cookies" style="color:#bd2426;">Please enable Cookies and reload the page.</p>
#     </div>
#   <script>
#   //<![CDATA[
#     var a = function() {try{return !!window.addEventListener} catch(e) {return !1} },
#       b = function(b, c) {a() ? document.addEventListener("DOMContentLoaded", b, c) : document.attachEvent("onreadystatechange", b)};
#       b(function(){
#         var cookiesEnabled=(navigator.cookieEnabled)? true : false;
#         if(!cookiesEnabled){
#           var q = document.getElementById('no-cookie-warning');q.style.display = 'block';
#         }
#       });
#   //]]>
#   </script>
#   <div id="trk_captcha_js" style="background-image:url('/cdn-cgi/images/trace/captcha/nojs/transparent.gif?ray=7330a1f87f6bc72c')"></div>
# </form>
#   <script>
#     //<![CDATA[
#     (function(){
#         var isIE = /(MSIE|Trident\/|Edge\/)/i.test(window.navigator.userAgent);
#         var trkjs = isIE ? new Image() : document.createElement('img');
#         trkjs.setAttribute("src", "/cdn-cgi/images/trace/managed/js/transparent.gif?ray=7330a1f87f6bc72c");
#         trkjs.id = "trk_managed_js";
#         trkjs.setAttribute("alt", "");
#         document.body.appendChild(trkjs);
#         var cpo=document.createElement('script');
#         cpo.type='text/javascript';
#         cpo.src = '/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=7330a1f87f6bc72c';
#
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, -window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window._cf_chl_opt.cUPMDTk && window.history && window.history.replaceState) {
#           var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#           history.replaceState(null, null, "\/en\/squads\/a2d435b3\/2020-2021\/Leicester-City-Stats?__cf_chl_rt_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0" + window._cf_chl_opt.cOgUHash);
#           cpo.onload = function() {
#             history.replaceState(null, null, ogU);
#           };
#         }
#
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#     //]]>
#     </script>
#
#
#               </div>
#             </div>
#
#             <div class="cf-column">
#               <div class="cf-screenshot-container">
#
#                 <span class="cf-no-screenshot"></span>
#
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#
#       <div class="cf-section cf-wrapper">
#         <div class="cf-columns two">
#           <div class="cf-column">
#             <h2 data-translate="why_captcha_headline">Why do I have to complete a CAPTCHA?</h2>
#
#             <p data-translate="why_captcha_detail">Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.</p>
#           </div>
#
#           <div class="cf-column">
#             <h2 data-translate="resolve_captcha_headline">What can I do to prevent this in the future?</h2>
#
#
#             <p data-translate="resolve_captcha_antivirus">If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.</p>
#
#             <p data-translate="resolve_captcha_network">If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.</p>
#
#
#
#           </div>
#         </div>
#       </div>
#
#
#       <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">7330a1f87f6bc72c</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">196.127.99.247</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
#   </div>
#
#   <script>
#   window._cf_translation = {};
#
#
# </script>
#
#
# </body>
# </html>
#
# https://fbref.com/en/squads/7c21e445/2020-2021/West-Ham-United-Stats
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
# <title>Please Wait... | Cloudflare</title>
#
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
#
#
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
#     window.addEventListener('DOMContentLoaded', function () {
#       var cookieEl = document.getElementById('cookie-alert');
#       cookieEl.style.display = 'block';
#     })
#   }
# </script>
# <!--<![endif]-->
#
#
#     <script>
#     //<![CDATA[
#     (function(){
#       window._cf_chl_opt={
#         cvId: "2",
#         cType: "managed",
#         cNounce: "53331",
#         cRay: "7330a1f90983c714",
#         cHash: "d50a5b537612ee0",
#         cUPMDTk: "\/en\/squads\/7c21e445\/2020-2021\/West-Ham-United-Stats?__cf_chl_tk=pBTDueT6Oj2eMP5r4iBhFRFvIBLmX7UyrPPstUGg_ak-1659210725-0-gaNycGzNBz0",
#         cFPWv: "g",
#         cTTimeMs: "1000",
#         cLt: "n",
#         cRq: {
#           ru: "aHR0cHM6Ly9mYnJlZi5jb20vZW4vc3F1YWRzLzdjMjFlNDQ1LzIwMjAtMjAyMS9XZXN0LUhhbS1Vbml0ZWQtU3RhdHM=",
#           ra: "cHl0aG9uLXJlcXVlc3RzLzIuMjUuMQ==",
#           rm: "R0VU",
#           d: "...",
#           t: "MTY1OTIxMDcyNS4yOTUwMDA=",
#           m: "/+9IOHXj6qtxHxuWynqG/AYGYdKRSoqOXRk8+6nNiYk=",
#           i1: "KAR8jLfNquZs0EAxmkH+bA==",
#           i2: "5WP6/K6vQE3N4PemYaYSqg==",
#           zh: "FFqr99jR/1GMyqpdyqWEB2vTdfc2EDuCZqDx8wF7Ek4=",
#           uh: "5GU+jYv2xJ+bCaE/ARmi/DORbiS/v56CW7E0TH4XWQk=",
#           hh: "chRDTXbssyxa+mhwwITbN4e9ZGrI2xuaPzXjtB81p0U=",
#         }
#       };
#     }());
#     //]]>
#     </script>
#
# <style>
#   #cf-wrapper #spinner {width:69px; margin:  auto;}
#   #cf-wrapper #cf-please-wait{text-align:center}
#   .attribution {margin-top: 32px;}
#   .bubbles { background-color: #f58220; width:20px; height: 20px; margin:2px; border-radius:100%; display:inline-block; }
#   #cf-wrapper #challenge-form { padding-top:25px; padding-bottom:25px; }
#   #cf-hcaptcha-container { text-align:center;}
#   #cf-hcaptcha-container iframe { display: inline-block;}
#   @keyframes fader     { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-wrapper #cf-bubbles { width:69px; }
#   @-webkit-keyframes fader { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-bubbles > .bubbles { animation: fader 1.6s infinite;}
# ...
#         if(!cookiesEnabled){
#           var q = document.getElementById('no-cookie-warning');q.style.display = 'block';
#         }
#       });
#   //]]>
#   </script>
#   <div id="trk_captcha_js" style="background-image:url('/cdn-cgi/images/trace/captcha/nojs/transparent.gif?ray=7330a2005f16c724')"></div>
# </form>
#   <script>
#     //<![CDATA[
#     (function(){
#         var isIE = /(MSIE|Trident\/|Edge\/)/i.test(window.navigator.userAgent);
#         var trkjs = isIE ? new Image() : document.createElement('img');
#         trkjs.setAttribute("src", "/cdn-cgi/images/trace/managed/js/transparent.gif?ray=7330a2005f16c724");
#         trkjs.id = "trk_managed_js";
#         trkjs.setAttribute("alt", "");
#         document.body.appendChild(trkjs);
#         var cpo=document.createElement('script');
#         cpo.type='text/javascript';
#         cpo.src = '/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=7330a2005f16c724';
#
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, -window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window._cf_chl_opt.cUPMDTk && window.history && window.history.replaceState) {
#           var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#           history.replaceState(null, null, "\/en\/squads\/60c6b05f\/2020-2021\/West-Bromwich-Albion-Stats?__cf_chl_rt_tk=2HqvJ3EM.SUu3vd_TPNNuxyyzRYkd16V89lPwpZIBqE-1659210726-0-gaNycGzNByU" + window._cf_chl_opt.cOgUHash);
#           cpo.onload = function() {
#             history.replaceState(null, null, ogU);
#           };
#         }
#
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#     //]]>
#     </script>
#
#
#               </div>
#             </div>
#
#             <div class="cf-column">
#               <div class="cf-screenshot-container">
#
#                 <span class="cf-no-screenshot"></span>
#
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#
#       <div class="cf-section cf-wrapper">
#         <div class="cf-columns two">
#           <div class="cf-column">
#             <h2 data-translate="why_captcha_headline">Why do I have to complete a CAPTCHA?</h2>
#
#             <p data-translate="why_captcha_detail">Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.</p>
#           </div>
#
#           <div class="cf-column">
#             <h2 data-translate="resolve_captcha_headline">What can I do to prevent this in the future?</h2>
#
#
#             <p data-translate="resolve_captcha_antivirus">If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.</p>
#
#             <p data-translate="resolve_captcha_network">If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.</p>
#
#
#
#           </div>
#         </div>
#       </div>
#
#
#       <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">7330a2005f16c724</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">196.127.99.247</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
#   </div>
#
#   <script>
#   window._cf_translation = {};
#
#
# </script>
#
#
# </body>
# </html>
#
# https://fbref.com/en/squads/1df6b87e/2020-2021/Sheffield-United-Stats
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
# <title>Please Wait... | Cloudflare</title>
#
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
#
#
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
#     window.addEventListener('DOMContentLoaded', function () {
#       var cookieEl = document.getElementById('cookie-alert');
#       cookieEl.style.display = 'block';
#     })
#   }
# </script>
# <!--<![endif]-->
#
#
#     <script>
#     //<![CDATA[
#     (function(){
#       window._cf_chl_opt={
#         cvId: "2",
#         cType: "managed",
#         cNounce: "42191",
#         cRay: "7330a200c85ec96d",
#         cHash: "3a44119639b3d29",
#         cUPMDTk: "\/en\/squads\/1df6b87e\/2020-2021\/Sheffield-United-Stats?__cf_chl_tk=2HqvJ3EM.SUu3vd_TPNNuxyyzRYkd16V89lPwpZIBqE-1659210726-0-gaNycGzNByU",
#         cFPWv: "g",
#         cTTimeMs: "1000",
#         cLt: "n",
#         cRq: {
#           ru: "aHR0cHM6Ly9mYnJlZi5jb20vZW4vc3F1YWRzLzFkZjZiODdlLzIwMjAtMjAyMS9TaGVmZmllbGQtVW5pdGVkLVN0YXRz",
#           ra: "cHl0aG9uLXJlcXVlc3RzLzIuMjUuMQ==",
#           rm: "R0VU",
#           d: "...",
#           t: "MTY1OTIxMDcyNi41MjYwMDA=",
#           m: "/7pW+R7WbnUxs6nWnpwOXc3geXkQAMyvHUoQCyxKqSs=",
#           i1: "P6C8bbiPtOfnb0N8Vrs6zg==",
#           i2: "r+F0xl/LOxpmLunyNDXRIA==",
#           zh: "FFqr99jR/1GMyqpdyqWEB2vTdfc2EDuCZqDx8wF7Ek4=",
#           uh: "5GU+jYv2xJ+bCaE/ARmi/DORbiS/v56CW7E0TH4XWQk=",
#           hh: "chRDTXbssyxa+mhwwITbN4e9ZGrI2xuaPzXjtB81p0U=",
#         }
#       };
#     }());
#     //]]>
#     </script>
#
# <style>
#   #cf-wrapper #spinner {width:69px; margin:  auto;}
#   #cf-wrapper #cf-please-wait{text-align:center}
#   .attribution {margin-top: 32px;}
#   .bubbles { background-color: #f58220; width:20px; height: 20px; margin:2px; border-radius:100%; display:inline-block; }
#   #cf-wrapper #challenge-form { padding-top:25px; padding-bottom:25px; }
#   #cf-hcaptcha-container { text-align:center;}
#   #cf-hcaptcha-container iframe { display: inline-block;}
#   @keyframes fader     { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-wrapper #cf-bubbles { width:69px; }
#   @-webkit-keyframes fader { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-bubbles > .bubbles { animation: fader 1.6s infinite;}
#   #cf-bubbles > .bubbles:nth-child(2) { animation-delay: .2s;}
#   #cf-bubbles > .bubbles:nth-child(3) { animation-delay: .4s;}
# </style>
# </head>
# <body>
#   <div id="cf-wrapper">
#     <div class="cf-alert cf-alert-error cf-cookie-error" id="cookie-alert" data-translate="enable_cookies">Please enable cookies.</div>
#     <div id="cf-error-details" class="cf-error-details-wrapper">
#       <div class="cf-wrapper cf-header cf-error-overview">
#
#         <h1 data-translate="managed_challenge_headline">Please wait...</h1>
#         <h2 class="cf-subheadline"><span data-translate="managed_checking_msg">We are checking your browser...</span> fbref.com</h2>
#
#       </div>
#
#       <div class="cf-section cf-highlight cf-captcha-container">
#         <div class="cf-wrapper">
#           <div class="cf-columns two">
#             <div class="cf-column">
#
#               <div class="cf-highlight-inverse cf-form-stacked">
#                 <form id="challenge-form" class="challenge-form managed-form" action="/en/squads/1df6b87e/2020-2021/Sheffield-United-Stats?__cf_chl_f_tk=2HqvJ3EM.SUu3vd_TPNNuxyyzRYkd16V89lPwpZIBqE-1659210726-0-gaNycGzNByU" method="POST" enctype="application/x-www-form-urlencoded">
#     <div id='cf-please-wait'>
#       <div id='spinner'>
#         <div id="cf-bubbles">
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#             <div class="bubbles"></div>
#         </div>
#       </div>
#       <p data-translate="please_wait" id="cf-spinner-please-wait">Please stand by, while we are checking your browser...</p>
#       <p data-translate="redirecting" id="cf-spinner-redirecting" style="display:none">Redirecting...</p>
#       </div>
#   <input type="hidden" name="md" value="cMkO2DyrtkbrqAXfTTGz8i5DW2M3okKWkz6Pbv2hiN4-1659210726-0-ATTeXYfyHc834zeFAjuV59a10asBzLqZpPZqKBniJAcNayGaWTCM8_l1lBQx0Bff9qij1NDCDWm3U0yc_CBxijC0yvlimMotmjy2HEs1EBWaXcFWy0NDQBeQJWHD0Ab3bicIKP8EYnjI8g5bH-H8PSYt-E5g0LfjVuRZjxm-q5gVpR5ilZkDpWAOUSqKwtX4Dzkrq6d0C1kfZEyNa3RDCeEbptaeIHwrzbjyfRE0cSV6BUcCRsMBQz_2OY-V-dT0TZIcOaq8mbAcsc28jIPlrG5sJswMKURyCUUcgf6HvtfNyedPTYe0QB_uO0HkbD1LYatZIER3pi5z_8G4LAbz_zm7AWXXmWJcOiKCg8VVvyfY8Wc1dOKH9vRn8YYvNSTqyWK9WlTQnKXZ4Qr-3I3AYjhXXdhpbuOprQjOjfC-tzCKWVEKeMedcb8dA4KvOf8m2hK97Y5DnjaLgUMessedyFwJU0saH4jaKI8y-g5WAIY5MPsM4TRVI8SNZhNIcH9uhHNjAOK52kn7a3sxK-eHTjJ2IOSeTlGf1F5MNO6yOga5XMZC6PDc4TuOLobbCB5Q-ROG95M18el1JhmfbrxsYpzoj0S_JSGguUiuRTFQhP-0ePO4ZmD9SPwHd4yfxGwPlmbl2Tf1OgxA9mdGCKg6zvyRbk1eTAWem9ky_9txMKGeyDD1JqrMqAGTLKfj4ZbI46bL04mkGfcSVVHDfbaaHfpY-V0Gv-6x6LPR54nvY4-fEq6c2hrI0xk0wKPDSJEkcaAF5go9AUyyb6mTssSb8VRpWvT2Fk7NMQOk4yZtpcFfs7mn23btTThDPGbotvrN9hS7ZRn8g6pDYez610zHsBtYr6Aa9EuajGH11cTeC92j" />
#   <input type="hidden" name="r" value="FIIC6YTSRMd1gTtoomefsvH4MkiU5wAeV2IYXrWDsl8-1659210726-0-...">
#   <noscript id="cf-captcha-bookmark" class="cf-captcha-info">
#   <h1 data-translate="turn_on_js" style="color:#bd2426;">Please turn JavaScript on and reload the page.</h1>
#   </noscript>
#     <div id="no-cookie-warning" class="cookie-warning" data-translate="turn_on_cookies" style="display:none">
#       <p data-translate="turn_on_cookies" style="color:#bd2426;">Please enable Cookies and reload the page.</p>
#     </div>
#   <script>
#   //<![CDATA[
#     var a = function() {try{return !!window.addEventListener} catch(e) {return !1} },
#       b = function(b, c) {a() ? document.addEventListener("DOMContentLoaded", b, c) : document.attachEvent("onreadystatechange", b)};
#       b(function(){
#         var cookiesEnabled=(navigator.cookieEnabled)? true : false;
#         if(!cookiesEnabled){
#           var q = document.getElementById('no-cookie-warning');q.style.display = 'block';
#         }
#       });
#   //]]>
#   </script>
#   <div id="trk_captcha_js" style="background-image:url('/cdn-cgi/images/trace/captcha/nojs/transparent.gif?ray=7330a200c85ec96d')"></div>
# </form>
#   <script>
#     //<![CDATA[
#     (function(){
#         var isIE = /(MSIE|Trident\/|Edge\/)/i.test(window.navigator.userAgent);
#         var trkjs = isIE ? new Image() : document.createElement('img');
#         trkjs.setAttribute("src", "/cdn-cgi/images/trace/managed/js/transparent.gif?ray=7330a200c85ec96d");
#         trkjs.id = "trk_managed_js";
#         trkjs.setAttribute("alt", "");
#         document.body.appendChild(trkjs);
#         var cpo=document.createElement('script');
#         cpo.type='text/javascript';
#         cpo.src = '/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=7330a200c85ec96d';
#
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, -window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window._cf_chl_opt.cUPMDTk && window.history && window.history.replaceState) {
#           var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#           history.replaceState(null, null, "\/en\/squads\/1df6b87e\/2020-2021\/Sheffield-United-Stats?__cf_chl_rt_tk=2HqvJ3EM.SUu3vd_TPNNuxyyzRYkd16V89lPwpZIBqE-1659210726-0-gaNycGzNByU" + window._cf_chl_opt.cOgUHash);
#           cpo.onload = function() {
#             history.replaceState(null, null, ogU);
#           };
#         }
#
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#     //]]>
#     </script>
#
#
#               </div>
#             </div>
#
#             <div class="cf-column">
#               <div class="cf-screenshot-container">
#
#                 <span class="cf-no-screenshot"></span>
#
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#
#       <div class="cf-section cf-wrapper">
#         <div class="cf-columns two">
#           <div class="cf-column">
#             <h2 data-translate="why_captcha_headline">Why do I have to complete a CAPTCHA?</h2>
#
#             <p data-translate="why_captcha_detail">Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.</p>
#           </div>
#
#           <div class="cf-column">
#             <h2 data-translate="resolve_captcha_headline">What can I do to prevent this in the future?</h2>
#
#
#             <p data-translate="resolve_captcha_antivirus">If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.</p>
#
#             <p data-translate="resolve_captcha_network">If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.</p>
#
#
#
#           </div>
#         </div>
#       </div>
#
#
#       <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">7330a200c85ec96d</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">196.127.99.247</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
#   </div>
#
#   <script>
#   window._cf_translation = {};
#
#
# </script>
#
#
# </body>
# </html>

# %%
len(all_matches)
# Out:
# 1

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time            comp         round  day venue result gf ga  \
# 1   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0  1
# 2   2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5  0
# 3   2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5  0
# 4   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1  0
# 6   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0  0
# ..         ...    ...             ...           ...  ...   ...    ... .. ..
# 38  2020-07-07  18:00  Premier League  Matchweek 34  Tue  Away      L  1  2
# 39  2020-07-11  12:30  Premier League  Matchweek 35  Sat  Home      L  0  4
# 40  2020-07-14  20:15  Premier League  Matchweek 36  Tue  Away      L  0  1
# 41  2020-07-18  17:30  Premier League  Matchweek 37  Sat  Home      L  0  2
# 42  2020-07-26  16:00  Premier League  Matchweek 38  Sun  Away      L  0  5
#
#            opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# 1         Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0
# 2      Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0
# 3           Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0
# 4    Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0
# 6       Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0
# ..              ...  ...           ...    ...   ...   ...   ...  ...  ...
# 38          Watford  ...  Match Report    NaN  13.0   3.0  16.1  1.0  0.0
# 39         West Ham  ...  Match Report    NaN  11.0   2.0  18.9  1.0  0.0
# 40          Chelsea  ...  Match Report    NaN   2.0   0.0  22.4  0.0  0.0
# 41          Burnley  ...  Match Report    NaN   6.0   2.0  12.9  0.0  0.0
# 42  Manchester City  ...  Match Report    NaN   5.0   4.0  18.6  0.0  0.0
#
#    pkatt season             team
# 1    0.0   2022  Manchester City
# 2    0.0   2022  Manchester City
# 3    0.0   2022  Manchester City
# 4    0.0   2022  Manchester City
# 6    0.0   2022  Manchester City
# ..   ...    ...              ...
# 38   0.0   2020     Norwich City
# 39   0.0   2020     Norwich City
# 40   0.0   2020     Norwich City
# 41   0.0   2020     Norwich City
# 42   0.0   2020     Norwich City
#
# [2112 rows x 27 columns]

# %%
match_df.to_csv("C:/Secure/docker/mybudget/h_compte/match_premier_league.csv")
